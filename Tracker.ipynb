# %%
from yahoofinancials import YahooFinancials

#4 major trading currency with MYR
yahoo_financials = YahooFinancials('MYR=X')
#refer to https://finance.yahoo.com/currencies?.tsrc=fin-srch for quote MYR/USD
print(yahoo_financials.get_historical_price_data("2019-02-01", "2019-03-01", "daily"))

yahoo_financials = YahooFinancials('JPYMYR=X')
#https://finance.yahoo.com/quote/JPYMYR=X/
print(yahoo_financials.get_historical_price_data("2019-02-01", "2019-03-01", "daily"))

yahoo_financials = YahooFinancials('EURMYR=X')
#https://finance.yahoo.com/quote/EURMYR=X/
print(yahoo_financials.get_historical_price_data("2019-02-01", "2019-03-01", "daily"))

yahoo_financials = YahooFinancials('GBPMYR=X')
#https://finance.yahoo.com/quote/GBPMYR=X/
print(yahoo_financials.get_historical_price_data("2019-02-01", "2019-03-01", "daily"))

yahoo_financials = YahooFinancials('CL=F')
#refers to Crude Oil Future in USD
print(yahoo_financials.get_historical_price_data("2019-02-01", "2019-03-01", "daily"))

yahoo_financials = YahooFinancials('BTC-USD')
#refers to BitCoin in USD
print(yahoo_financials.get_historical_price_data("2019-01-01", "2019-03-01", "daily"))
# Out:
# {'MYR=X': {'eventsData': {}, 'firstTradeDate': {'formatted_date': '2003-12-01', 'date': 1070236800}, 'currency': 'MYR', 'instrumentType': 'CURRENCY', 'timeZone': {'gmtOffset': 0}, 'prices': [{'date': 1548979200, 'high': 4.094099998474121, 'low': 4.080900192260742, 'open': 4.093999862670898, 'close': 4.093999862670898, 'volume': 0, 'adjclose': 4.093999862670898, 'formatted_date': '2019-02-01'}, {'date': 1549238400, 'high': 4.098999977111816, 'low': 4.083399772644043, 'open': 4.0980000495910645, 'close': 4.0929999351501465, 'volume': 0, 'adjclose': 4.0929999351501465, 'formatted_date': '2019-02-04'}, {'date': 1549324800, 'high': 4.090000152587891, 'low': 4.075500011444092, 'open': 4.084499835968018, 'close': 4.084499835968018, 'volume': 0, 'adjclose': 4.084499835968018, 'formatted_date': '2019-02-05'}, {'date': 1549411200, 'high': 4.0868000984191895, 'low': 4.075500011444092, 'open': 4.075500011444092, 'close': 4.090000152587891, 'volume': 0, 'adjclose': 4.090000152587891, 'formatted_d
# ...
